# %%
# !zip -r neural_gcm.zip neural_gcm
# Out:
# Scanning files ....... .
# updating: neural_gcm/ (stored 0%)
# updating: neural_gcm/run_nextgems_2049_drift.sbatch (deflated 39%)
# updating: neural_gcm/results_daily_nextgems/ (stored 0%)
# updating: neural_gcm/results_daily_nextgems/nextgems_2049_drift_yearmean.csv (deflated 52%)
# updating: neural_gcm/results_daily_nextgems/truth_modelgrid_T_native_2049.nc (deflated 0%)
# updating: neural_gcm/results_daily_nextgems/nextgems_2049_reference_gmean.csv (deflated 68%)
# updating: neural_gcm/results_daily_nextgems/nextgems_2049_drift_yearmean_i50.csv (deflated 55%)
# updating: neural_gcm/results_daily_nextgems/nextgems_2049_drift_maps_i50.nc (deflated 30%)
# updating: neural_gcm/results_daily_nextgems/truth_modelgrid_T_2049.nc (deflated 19%)
# updating: neural_gcm/results_daily_nextgems/nextgems_2049_rollout_gmean_i50.csv (deflated 71%)
# updating: neural_gcm/results_daily_nextgems/nextgems_2049_drift_per_init_i50.csv (deflated 61%)
# ...
